# %% [markdown]
# # aquí hicimos este pedo

# %%
print('hello wor')
# Out:
# hello wor

# %%
# lista = [1,2,3,4,5]
for item in lista:
    print(item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-14199100f037> in <module>()
#       1 # lista = [1,2,3,4,5]
# ----> 2 for item in lista:
#       3     print(item)
#
# NameError: name 'lista' is not defined

# %% [markdown]
# # for

# %%
x = input("Lista:")
for i in x:
    print(i)
# Out:
# Lista:[1,2,3,4]
# [
# 1
# ,
# 2
# ,
# 3
# ,
# 4
# ]
